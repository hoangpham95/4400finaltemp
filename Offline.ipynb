# %%
import re
from os import listdir
from os.path import isfile, join
import csv
import os
import pandas as pd
import time
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
train_dir = '/home/hoang/Downloads/train/'
files = [f for f in listdir(train_dir) if isfile(join(train_dir, f))]

# %%
class CSVProcessor:
    def __init__(self, fdir, fname):
        self.fdir = fdir
        self.fname = fname
        
    def process(self):
        line = 0
        df = pd.read_csv(filepath_or_buffer=os.path.join(self.fdir, self.fname))
        return df

# %%
proc = CSVProcessor('data/', 'trainLabels.csv')
df = proc.process()

data, _ = train_test_split(df, test_size=0.6, random_state=42) # train on 40% given data

train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
proc.process()
# Out:
#                          Id  Class
# 0      01kcPWA9K2BOxQeS5Rju      1
# 1      04EjIdbPV5e1XroFOpiN      1
# 2      05EeG39MTRrI6VY21DPd      1
# 3      05rJTUWYAKNegBk2wE8X      1
# 4      0AnoOZDNbPXIr2MRBSCJ      1
# 5      0AwWs42SUQ19mI7eDcTC      1
# 6      0cH8YeO15ZywEhPrJvmj      1
# 7      0DNVFKwYlcjO7bTfJ5p1      1
# 8      0DqUX5rkg3IbMY6BLGCE      1
# 9      0eaNKwluUmkYdIvZ923c      1
# 10     0fHVZKeTE6iRb1PIQ4au      1
# 11     0G4hwobLuAzvl1PWYfmd      1
# 12     0gkj92oIleU4SYiCWpaM      1
# 13     0H63jydvIahOVqgx5Kfo      1
# 14     0Hrfce4X5YGESJPjl9uL      1
# 15     0I4ZVvngsAatm8fzD3pk      1
# 16     0iBaz3krsQ8HuA7cGDSt      1
# 17     0iS3pwlgJco8XORD4TLq      1
# 18     0jkmvR43UQ9yKxqXei61      1
# 19     0KigmP9TLwJXNGz26tfO      1
# 20     0l6fhCty3aSLDOgAjYQi      1
# 21     0MOorvEIRmZGhqQdc3TA      1
# 22     0NEsQlDGnUMg3Bew7R1A      1
# 23     0NyfGXt8nmlK72Q9Irhs      1
# 24     0odUVkrjp2B1n8NDS6bR      1
# 25     0pTO4SVnWDehgUlYBAvq      1
# 26     0qpMX5CZU8mgD2kaRNVv      1
# 27     0Rgetc1wAfxlzHTGBOa7      1
# 28     0rgudc7PpbexCtBjNqWF      1
# 29     0S7z4qxYTHPUDO8fgIyA      1
# ...                     ...    ...
# 10838  jTgF9SKzb8qxdsC6NnmY      9
# 10839  JUCpOmLGibKr7gdPHfhj      9
# 10840  JudsxDwAcT2XRjZkC7Yv      9
# 10841  jvdbriZknaRP9emq2Lp0      9
# 10842  jVEk2G0fyQUiNWbxAzch      9
# 10843  JVPnwpfeExcNDt2ZTAQm      9
# 10844  jwgxPFMNGtXKTYkio0rI      9
# 10845  JwYGzbH8uaAhnTiFIEWv      9
# 10846  JwzA3tXdgc7eNYxjCy5L      9
# 10847  JyBvMAZbhIprolF8HNe6      9
# 10848  JyExpTqVMmeA2wH0FbkY      9
# 10849  jZfoAgI4BUzQne1lY5hP      9
# 10850  jztINZ6PGKThubQ78fWk      9
# 10851  JZX2B0zdS7MAVmjLUkx6      9
# 10852  k1fj8xVnJ5vWaT2dUsoC      9
# 10853  K4jGPJV6DUu7Xq1eFdrB      9
# 10854  k6Mnj2POrsKEqVxeNJAu      9
# 10855  K70AVwRbXjTFZv9g463D      9
# 10856  K73w4anvIFEZi96dxtA5      9
# 10857  K7HTMuk6fo2wrhyWxY43      9
# 10858  k8qrhNTAG54fSl6jDtVa      9
# 10859  K94VFOcjXG0dUkDtMln3      9
# 10860  kAtomObScfxVW1DKXUla      9
# 10861  kchO8uQA9Me4H3jZTSgm      9
# 10862  KF7NGoQSk8v9OE0nrwy2      9
# 10863  KFrZ0Lop1WDGwUtkusCi      9
# 10864  kg24YRJTB8DNdKMXpwOH      9
# 10865  kG29BLiFYPgWtpb350sO      9
# 10866  kGITL4OJxYMWEQ1bKBiP      9
# 10867  KGorN9J6XAC4bOEkmyup      9
#
# [10868 rows x 2 columns]

# %%
train_hashes = [x for x in train['Id']]
train_class = [x for x in train['Class']]

# %%
SECTION_PREF = [
    'HEADER:', '.text:', '.Pav:', '.idata', '.data', '.rdata', '.bss', '.edata:',
    '.rsrc:', '.tls', '.reloc:'
]

OP_INSTR = [
    'jmp', 'mov', 'retf', 'push', 'pop', 'xor', 'retn', 'nop', 'sub', 'inc', 'dec', 'add',
    'imul', 'xchg', 'or', 'shr', 'cmp', 'call', 'shl', 'ror', 'rol', 'jnb'
]

KEY = ['.dll', 'std::', ':dword']

# important keyword to interact with stack and manipulate memories
MEM_KW = ['FUNCTION', 'call'] # memcpy_s and memmove_s usually comes after call

# %%
class Preprocess:
    def __init__(self, files, min_app=30, num_top_features=5000):
        self.files = files
        self.min_app = min_app
        self.num_top_features = num_top_features
        
    def genTokenAsm(self, file):
        asm = join(train_dir, file + ".asm")
        byte = join(train_dir, file + ".bytes")
        
        with open(asm, 'r', encoding='ISO-8859-1') as asmFile:
            tokens = re.sub(r'\t|\n|\r', ' ', asmFile.read()).split()
        
        filtered = []
        opList = []
        
        for i in range(1, len(tokens) - 1):
            if tokens[i] in OP_INSTR:
                filtered.append(tokens[i])
                opList.append(tokens[i])
            
            filtered += [p for p in SECTION_PREF if p in tokens[i]]
            filtered += [k for k in KEY if k in tokens[i]]
            filtered += [tokens[i] + ' ' + tokens[i + 1] for k in MEM_KW if k == tokens[i]]
            
            # memory and function call
            if tokens[i] == '__stdcall':
                bigram = tokens[i] + ' ' + tokens[i + 1].partition('(')[0]
                filtered.append(bigram)
                filtered.append(tokens[i - 1])
            
            # define bytes
            if tokens[i] == 'db' and tokens[i + 1][0] == "'":
                filtered.append(tokens[i] + ' ' + tokens[i + 1])
        
        counts = {}
        for i in filtered:
            counts[i] = counts.get(i, 0) + 1
        
        return counts
    
    def genBagOfWordsPerFile(self, tok_map, glob_dict):
        ret = {}
        for w in glob_dict:
            ret[w] = (tok_map.get(w, 0) * 1.0) / glob_dict[w]
        return ret
    
    def getBytesAndAsmSize(self, f):
        asm = join(train_dir, f + ".asm")
        b = join(train_dir, f + ".bytes")
        return {"asm": os.stat(asm).st_size, "bytes": os.stat(b).st_size}
                
    
    def process(self):
        glob_dict = {}
        asm_map = {}
        print("Start processing files")
        start = time.time()
        
        for f in self.files:
#             print("=> Generate token for", f)
            freq = self.genTokenAsm(f)
            asm_map[f + ".asm"] = freq
            for tok in freq:
                glob_dict[tok] = glob_dict.get(tok, 0) + freq[tok]
            
        glob_dict = {k:v for (k,v) in glob_dict.items() if v >= self.min_app}
        glob_features = list(glob_dict.keys())
        df = pd.DataFrame(columns=(['file'] + glob_features) + ['asm_sz', 'byte_sz'])
        
        # top features
        sz = min(len(glob_features), self.num_top_features)
        glob_features = sorted(glob_features, key=lambda x: -glob_dict[x])
        top_features = glob_features[:sz]
        
        new_glob_dict = {}
        for f in top_features:
            new_glob_dict[f] = glob_dict.get(f, 0)
            
        
        for f in self.files:
            bag = self.genBagOfWordsPerFile(asm_map[f + ".asm"], new_glob_dict)
            sz = self.getBytesAndAsmSize(f)
            
            bag['file'] = f
            bag['asm_sz'] = sz['asm']
            bag['byte_sz'] = sz['bytes']
            
            df = df.append(bag, ignore_index=True)
        print("Done processing files after", ((time.time() - start) * 1.0 / 60), "minutes")
        return (df, top_features)

# %%
pre = Preprocess(train_hashes[:100])
df, top = pre.process()

# %%
df

# %%
df.insert(44, 'label', train_class[:100])

# %%
df['label']

# %%
from sklearn.feature_selection import SelectKBest, chi2

selector = SelectKBest(chi2, k=50).fit(df.drop(columns=['file', 'label']), df['label'])

# %%
selector.get_params()
selector.scores_.shape

# %%
c = len(df.columns)
c = df.columns[1:c-1]
d = dict(zip(c, selector.scores_))

# %%
len(c)

# %%
sorted(c, key=lambda x: -d[x])[:100]

# %%
X_new.shape

# %%
top

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators=10, max_depth=8, max_features=int(np.sqrt(83)), n_jobs=3)

# %%
rfc.fit(df.drop(columns=['file']), train['Class'][:100])

# %%
rfc.score(df.drop(columns=['file']), train['Class'][:100])

# %%
rfc = RandomForestClassifier(n_estimators=200, max_depth=8, max_features=int(np.sqrt(16590)), n_jobs=3)

# %%
rfc.fit(df.drop(columns=['file']), train['Class'])

# %%
from asm_proc import ASMProcess

# %%
proc = ASMProcess(train_dir, train_hashes[:2], train_class[:2], 30, 10)

# %%
df, top = proc.process()
# Out:
# Start processing files
#                    file    .text:       mov     retn  sub  xor      push  \
# 0  BOEePDvjdtscGrZwKloT  0.443811  0.901797  0.86922  NaN  NaN  0.930324
# 1  7vjsWlX3rQL1dNenwTxV  0.556189  0.098203  0.13078  NaN  NaN  0.069676
#
#        call  inc       pop  ...    call __SEH_epilog  call sub_1002A4A9  BOOL  \
# 0  0.927179  NaN  0.913317  ...                  NaN                NaN   NaN
# 1  0.072821  NaN  0.086683  ...                  NaN                NaN   NaN
#
#    .dll  .idata  call ??3@YAXPAX@Z  call unknown_libname_3    asm_sz  byte_sz  \
# 0   NaN     NaN                NaN                     NaN   7174112  2197504
# 1   NaN     NaN                NaN                     NaN  19267478  9265152
#
#    label
# 0      1
# 1      2
#
# [2 rows x 55 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1240c9ebe0a6> in <module>()
# ----> 1 df, top = proc.process()
#
# ~/Documents/school/4400/final/asm_proc.py in process(self)
#     116         print(df)
#     117
# --> 118         df, top_features = self.get_top_features(df)
#     119         print("Done processing [asm] files after",
#     120               ((time.time() - start) * 1.0 / 60), "minutes")
#
# ~/Documents/school/4400/final/asm_proc.py in get_top_features(self, df)
#     124         sub_df = df.drop(columns=['file', 'label'])
#     125         selector = SelectKBest(chi2, k=self.num_top_features).fit(
# --> 126             sub_df, df['label'])
#     127         scores = selector.scores_
#     128         d = dict(zip(sub_df.columns, scores))
#
# ~/Documents/school/4400/env/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py in fit(self, X, y)
#     339             Returns self.
#     340         """
# --> 341         X, y = check_X_y(X, y, ['csr', 'csc'], multi_output=True)
#     342
#     343         if not callable(self.score_func):
#
# ~/Documents/school/4400/env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/Documents/school/4400/env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~/Documents/school/4400/env/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
